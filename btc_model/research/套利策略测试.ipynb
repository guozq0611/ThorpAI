# %%
# %load_ext autoreload
# %autoreload 2

# %%
from btc_model.trade.arbitrage_position_manager import ArbitragePositionManager
from btc_model.trade.arbitrage_position_manager import get_arbitrage_position_manager
from btc_model.core.market.market_data_service import MarketDataService
# Out:
# /Users/Jason/work/source/03_ThorpAI/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# INFO   : 2025-03-14 18:38:47,878 >>> NumExpr defaulting to 8 threads.

# %%
test_arbitrage_position_manager()
# Out:
# INFO   : 2025-03-14 18:38:55,150 >>> MarketDataService initialized
# INFO   : 2025-03-14 18:38:55,150 >>> 添加交易所: exchange_1
# INFO   : 2025-03-14 18:38:55,164 >>> 创建 binance 的异步交易所实例成功
# INFO   : 2025-03-14 18:38:55,164 >>> 创建 ccxtpro 实例: exchange_1
# INFO   : 2025-03-14 18:38:55,165 >>> 添加交易所: exchange_2
# INFO   : 2025-03-14 18:38:55,175 >>> 创建 okx 的异步交易所实例成功
# INFO   : 2025-03-14 18:38:55,176 >>> 创建 ccxtpro 实例: exchange_2
# INFO   : 2025-03-14 18:38:55,177 >>> 添加交易所: exchange_hedge
# INFO   : 2025-03-14 18:38:55,191 >>> 创建 binance 的异步交易所实例成功
# INFO   : 2025-03-14 18:38:55,192 >>> 创建 ccxtpro 实例: exchange_hedge
# INFO   : 2025-03-14 18:38:55,193 >>> subscribe orderbook: exchange_1:LSK/USDT
# INFO   : 2025-03-14 18:38:55,194 >>> subscribe orderbook: exchange_2:LSK/USDT
# INFO   : 2025-03-14 18:38:55,195 >>> subscribe orderbook: exchange_hedge:LSK/USDT:USDT
# INFO   : 2025-03-14 18:38:55,196 >>> subscribe funding rate: exchange_hedge:LSK/USDT:USDT
# ...

# %%
md = MarketDataService()
# Out:
# WARNING: 2025-03-14 18:41:48,563 >>> okx requires to release all resources with an explicit call to the .close() coroutine. If you are using the exchange instance with async coroutines, add `await exchange.close()` to your code into a place when you're done with the exchange and don't need the exchange instance anymore (at the end of your async coroutine).
# WARNING: 2025-03-14 18:41:48,563 >>> binance requires to release all resources with an explicit call to the .close() coroutine. If you are using the exchange instance with async coroutines, add `await exchange.close()` to your code into a place when you're done with the exchange and don't need the exchange instance anymore (at the end of your async coroutine).
# ...
